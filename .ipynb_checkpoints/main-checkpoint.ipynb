# %% [markdown]
# # Data Cleaning project
# A pre-EDA step.

# %%
import pandas as pd

# %%
import pathlib
pathlib.Path().absolute()
# Out:
# WindowsPath('C:/Users/rafal.klat')

# %%
# OGARNĄĆ I OPISAĆ ŹRÓDŁO
# https://www.quora.com/Where-can-I-get-messy-data-to-work-on-data-cleaning-skills

# %%
print(len(df['Project ID'].unique()))
print(len(df['Project ID']))
# Out:
# 2468
# 2468

# %%
print(len(df[['Unique Investment Identifier', 'Business Case ID']].drop_duplicates()))
print(len(df['Unique Investment Identifier'].unique()))
print(len(df['Business Case ID'].unique()))
# Out:
# 599
# 599
# 599

# %%
print('len(code):', len(df['Agency Code'].unique()), ', len(name):', len(df['Agency Name'].unique()))
print('len(both):', len(df[['Agency Code', 'Agency Name']].drop_duplicates()))
# print(df['Agency Code'].unique())
# print(df['Agency Name'].unique())
print(df[['Agency Code', 'Agency Name']].drop_duplicates())
df[(df['Agency Code'] == 6.0) & (df['Agency Name'] != 'Department of Commerce')]
# len(df[(df['Agency Code'] == 6.0)])

df.head(55)
# Out:
# len(code): 26 , len(name): 26
# len(both): 27
#       Agency Code                                    Agency Name
# 0             5.0                      Department of Agriculture
# 9             6.0                      Department of Agriculture
# 173           6.0                         Department of Commerce
# 449           7.0                          Department of Defense
# 623           9.0        Department of Health and Human Services
# 842          10.0                     Department of the Interior
# 882          11.0                          Department of Justice
# 925          12.0                            Department of Labor
# 1052         14.0                            Department of State
# 1124         15.0                     Department of the Treasury
# 1236         16.0                 Social Security Administration
# 1350         18.0                        Department of Education
# 1400         19.0                           Department of Energy
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2468 entries, 0 to 2492
# Data columns (total 23 columns):
# Unique Investment Identifier                     2468 non-null object
# Business Case ID                                 2468 non-null float64
# Agency Code                                      2468 non-null float64
# Agency Name                                      2468 non-null object
# Investment Title                                 2468 non-null object
# Project ID                                       2468 non-null float64
# Agency Project ID                                1313 non-null object
# Project Name                                     2468 non-null object
# Project Description                              2468 non-null object
# Start Date                                       2451 non-null object
# Completion Date (B1)                             2451 non-null object
# Planned Project Completion Date (B2)             1547 non-null object
# ...

# %%
# There are rows with Totals. It doesn't add any value, but only complicates the analysis.
indices_to_drop = df.loc[df['Business Case ID'].isna()].index
df.drop(indices_to_drop, inplace=True)

# %%
df['Investment Title'].value_counts()
# Out:
# Medical Legacy                                                                                                     74
# USPTO Network and Security Infrastructure                                                                          51
# HRSA - OIT Electronic Handbooks (EHBs)                                                                             46
# USPTO Patents End-to-End: Software Engineering (PE2E-SE)                                                           29
# Optimized Computing Environment (OCE)                                                                              28
# InterAgency 21st Century-One Vet                                                                                   26
# Corporate 21st Century Core                                                                                        22
# USCIS - Immigration - CLAIMS 3.0                                                                                   21
# ...

# %%
df.head(5)
# Out:
#   Unique Investment Identifier  Business Case ID  Agency Code  \
# 0                005-000001723             212.0          5.0
# 1                005-000001723             212.0          5.0
# 2                005-000001723             212.0          5.0
# 3                005-000001822             213.0          5.0
# 4                005-000001822             213.0          5.0
#
#                  Agency Name                            Investment Title  \
# 0  Department of Agriculture     AMS Infrastructure WAN and DMZ (AMSWAN)
# 1  Department of Agriculture     AMS Infrastructure WAN and DMZ (AMSWAN)
# 2  Department of Agriculture     AMS Infrastructure WAN and DMZ (AMSWAN)
# 3  Department of Agriculture  APHIS Electronic Permits System (ePermits)
# 4  Department of Agriculture  APHIS Electronic Permits System (ePermits)
#
#    Project ID Agency Project ID               Project Name  \
# 0       656.0               NaN                 Operations
# ...

# %%
# todo:

# Unique Investment Identifier - czy tam zawsze jest 005?
#Business Case ID, Agency Code, Project ID - wyglada, ze to moga byc inty
# Agency Name - moze to sa tylko departamenty?
# dates i times -> timestamps
# Cost Variance - dobre jednostki? 
# unique porojet id moze jako pierwsze/drugie?
# NaN -> None/null
# project name - powtarzaja sie, ale prawie (np. 3 i 4)
# inny index (któreś ID)
# project ID vs unique project ID
# czy w Agency Project ID cos w ogole jkest?
# ID vs Identifier
# 1 kolumna z unique ID nie jest unique


#sprawdzic unique values
# info() - tylko objects i float64
# describe()
# min i max

# %% [markdown]
# General problems:
# * Data types: only `object` and `float64`
#
# Columns and problems with them:
# 1. `Unique Investment Identifier`:
#     1. not unique, despite the name.
# 	2. **Identifier** could be **ID**.
# 2. `Business Case ID`
# 	1. it is float, but should be int or string.
# 	2. it corresponds 1:1 with `Unique Investment Identifier`, so it should be kept in another lookup table.
# 3. `Agency Code`
# 	1. **Code** could be **ID**.
# 4. `Agency Name`
# 	1. It corresponds 1:1 with `Agency Code`, so it should be kept in another lookup table.
# 5. `Investment Title`
#     1. Minor formatting problems (e.g. '&amp;' instead of '&').
# 6. `Project ID`
#
# 7. `Agency Project ID`
# 8. `Project Name`
# 9. `Project Description`
# 10. `Start Date`
# 11. `Completion Date (B1)`
# 12. `Planned Project Completion Date (B2)`
# 13. `Projected/Actual Project Completion Date (B2)`
# 14. `Lifecycle Cost`
# 15. `Schedule Variance (in days)`
# 16. `Schedule Variance (%)`
# 17. `Cost Variance ($ M)`
# 18. `Cost Variance (%)`
# 19. `Planned Cost ($ M)`
# 20. `Projected/Actual Cost ($ M)`
# 21. `Updated Date`
# 22. `Updated Time`
# 23. `Unique Project ID`
#
# Uwagi:
#
# 4.1. There are only two cases in whole DataFrame, where `Agency Code` doesn't reflect `Agency Name` ideally. By comparing lengths of `Agency Code`, `Agency Name` and pair of these two, we see that there is **one more of unique entries** within Code+Name pair. Quick look at pairs:
#
# print(df[['Agency Code', 'Agency Name']].drop_duplicates())
#
# and wee see that only `6.0` is our point of pain. These filtering:
#
# df[(df['Agency Code'] == 6.0) & (df['Agency Name'] != 'Department of Commerce')]
#
# results in two entries, which have wrong `Agency Code` values (not `Agency Name`, what can be easily deduced from other entries): it should be `5.0`.
